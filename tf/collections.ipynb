# %% [markdown]
# https://www.tensorflow.org/versions/r1.15/api_docs/python/tf/add_to_collection
# https://www.tensorflow.org/versions/r1.15/api_docs/python/tf/add_to_collections
# https://www.tensorflow.org/versions/r1.15/api_docs/python/tf/get_collection
# https://www.tensorflow.org/versions/r1.15/api_docs/python/tf/get_collection_ref
